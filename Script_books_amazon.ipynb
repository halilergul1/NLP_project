# %%
# Import the os module
import os

# Get the current working directory
cwd = os.getcwd()

# Print the current working directory
print("Current working directory: {0}".format(cwd))

# Print the type of the returned object
print("os.getcwd() returns an object of type: {0}".format(type(cwd)))
# Out:
# Current working directory: C:\Users\ibrah\Desktop\Koç Uni\2. Spring Dönemi, Dersler\CSSM 530\python
# os.getcwd() returns an object of type: <class 'str'>

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ibrah\\Desktop\\Koç Uni\\2. Spring Dönemi, Dersler\\CSSM 530\\python'

# %%
import pandas as pd
import numpy as np
from collections import Counter


df = pd.read_csv('amazon_reviews_us_Books_v1_02.tsv', sep='\t', header=None, on_bad_lines='skip')

print(df.head())
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (1,4,7,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             0            1               2           3               4   \
# 0  marketplace  customer_id       review_id  product_id  product_parent
# 1           US     12076615   RQ58W7SMO911M  0385730586       122662979
# 2           US     12703090    RF6IUKMGL8SF  0811828964        56191234
# 3           US     12257412  R1DOSHH6AI622S  1844161560       253182049
# 4           US     50732546   RATOTLA3OF70O  0373836635       348672532
#
#                                               5                 6   \
# 0                                  product_title  product_category
# 1     Sisterhood of the Traveling Pants (Book 1)             Books
# 2  The Bad Girl's Guide to Getting What You Want             Books
# 3         Eisenhorn (A Warhammer 40,000 Omnibus)             Books
# 4                Colby Conspiracy (Colby Agency)             Books
#
#             7              8            9     10                 11  \
# 0  star_rating  helpful_votes  total_votes  vine  verified_purchase
# 1            4              2            3     N                  N
# 2            3              5            5     N                  N
# 3            4              1           22     N                  N
# 4            5              2            2     N                  N
#
#                                       12  \
# 0                        review_headline
# 1  this book was a great learning novel!
# 2                              Fun Fluff
# 3                    this isn't a review
# 4              fine author on her A-game
#
#                                                   13           14
# 0                                        review_body  review_date
# 1  this boook was a great one that you could lear...   2005-10-14
# 2  If you are looking for something to stimulate ...   2005-10-14
# 3  never read it-a young relative idicated he lik...   2005-10-14
# 4  Though she is honored to be Chicago Woman of t...   2005-10-14

# %%
df.shape
df.info()
len(df.columns)


df.isnull().sum().sum()

df['review_body'].isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3105371 entries, 0 to 3105370
# Data columns (total 15 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   0       object
#  1   1       object
#  2   2       object
#  3   3       object
#  4   4       object
#  5   5       object
#  6   6       object
#  7   7       object
#  8   8       object
#  9   9       object
#  10  10      object
#  11  11      object
#  12  12      object
#  13  13      object
#  14  14      object
# dtypes: object(15)
# memory usage: 355.4+ MB
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'review_body'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17720/3143282358.py in <module>
#       6 df.isnull().sum().sum()
#       7
# ----> 8 df['review_body'].isnull().sum()
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'review_body'

# %%
import numpy as np

df.isnull().sum().sum()
# Out:
# 199

# %%
df.columns = ['marketplace', 'customer_id', 'review_id', 'product_id', 'product_parent', 'product_title', 'product_category', 'star_rating', 
            'helpful_votes', 'total_votes', 'vine', 'verified_purchase', 'review_headline', 'review_body', 'review_date']

print(df.head())
# Out:
#    marketplace  customer_id       review_id  product_id  product_parent  \
# 0  marketplace  customer_id       review_id  product_id  product_parent
# 1           US     12076615   RQ58W7SMO911M  0385730586       122662979
# 2           US     12703090    RF6IUKMGL8SF  0811828964        56191234
# 3           US     12257412  R1DOSHH6AI622S  1844161560       253182049
# 4           US     50732546   RATOTLA3OF70O  0373836635       348672532
#
#                                    product_title  product_category  \
# 0                                  product_title  product_category
# 1     Sisterhood of the Traveling Pants (Book 1)             Books
# 2  The Bad Girl's Guide to Getting What You Want             Books
# 3         Eisenhorn (A Warhammer 40,000 Omnibus)             Books
# 4                Colby Conspiracy (Colby Agency)             Books
#
#    star_rating  helpful_votes  total_votes  vine  verified_purchase  \
# 0  star_rating  helpful_votes  total_votes  vine  verified_purchase
# 1            4              2            3     N                  N
# 2            3              5            5     N                  N
# 3            4              1           22     N                  N
# 4            5              2            2     N                  N
#
#                          review_headline  \
# 0                        review_headline
# 1  this book was a great learning novel!
# 2                              Fun Fluff
# 3                    this isn't a review
# 4              fine author on her A-game
#
#                                          review_body  review_date
# 0                                        review_body  review_date
# 1  this boook was a great one that you could lear...   2005-10-14
# 2  If you are looking for something to stimulate ...   2005-10-14
# 3  never read it-a young relative idicated he lik...   2005-10-14
# 4  Though she is honored to be Chicago Woman of t...   2005-10-14

# %%
data = pd.DataFrame(df)

# print(data.head())

# type(data)

# print(data)

data = df.iloc[1:, :]

# print(data)

from IPython.display import display

display(data.head())

# df['review_body'].isnull().sum()
# Out:
#   marketplace customer_id       review_id  product_id product_parent  \
# 1          US    12076615   RQ58W7SMO911M  0385730586      122662979
# 2          US    12703090    RF6IUKMGL8SF  0811828964       56191234
# 3          US    12257412  R1DOSHH6AI622S  1844161560      253182049
# 4          US    50732546   RATOTLA3OF70O  0373836635      348672532
# 5          US    51964897  R1TNWRKIVHVYOV  0262181533      598678717
#
#                                        product_title product_category  \
# 1         Sisterhood of the Traveling Pants (Book 1)            Books
# 2      The Bad Girl's Guide to Getting What You Want            Books
# 3             Eisenhorn (A Warhammer 40,000 Omnibus)            Books
# 4                    Colby Conspiracy (Colby Agency)            Books
# 5  The Psychology of Proof: Deductive Reasoning i...            Books
#
#   star_rating helpful_votes total_votes vine verified_purchase  \
# 1           4             2           3    N                 N
# 2           3             5           5    N                 N
# 3           4             1          22    N                 N
# 4           5             2           2    N                 N
# 5           4             0           2    N                 N
#
#                          review_headline  \
# 1  this book was a great learning novel!
# 2                              Fun Fluff
# 3                    this isn't a review
# 4              fine author on her A-game
# 5          Execellent cursor examination
#
#                                          review_body review_date
# 1  this boook was a great one that you could lear...  2005-10-14
# 2  If you are looking for something to stimulate ...  2005-10-14
# 3  never read it-a young relative idicated he lik...  2005-10-14
# 4  Though she is honored to be Chicago Woman of t...  2005-10-14
# 5  Review based on a cursory examination by Unive...  2005-10-14

# %%
import matplotlib.pyplot as plt

# %%
def len_of_str(x):
    if type(x) != float:
        leng = len(x)
    else:
        leng = 0
    return leng

plt.hist(data['review_body'].apply(len_of_str), range=[0, 1000], facecolor='gray', align='mid')
# Out:
# (array([ 59784., 214333., 323041., 347699., 323746., 283348., 233594.,
#         189516., 156500., 130523.]),
#  array([   0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,  800.,
#          900., 1000.]),
#  <BarContainer object of 10 artists>)

# %%
sozluk = {'Psychology' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}
sozluk2 = {'Psychology' : 0}

sozluk['Psychology']
def psy(x):
    if 'psych' in x.lower():
        a = 1
    else:
        a = 0
    return a

data['product_title'].apply(psy).sum()
# Out:
# 12983

# %%
list_of_titles = data['product_title'].to_list()

# print('List of Names: ', list_of_titles)

list_of_titles


from collections import Counter
# counts = Counter(list_of_titles)
# print(counts)

def soc(x):
    if 'sociology' in x.lower():
        a = 1
    else: 
        a = 0
    return a




data['product_title'].apply(soc).sum()
# Out:
# 455

# %%
# from nltk.tokenize import word_tokenize


# tokenized_sents = [word_tokenize(i) for i in list_of_titles]

# print(type(tokenized_sents))

# print(f'"Psychology" appears {counts["Psychology"]} time(s)')


# print(tokenized_sents[1:20])
# Out:
# [['The', 'Bad', 'Girl', "'s", 'Guide', 'to', 'Getting', 'What', 'You', 'Want'], ['Eisenhorn', '(', 'A', 'Warhammer', '40,000', 'Omnibus', ')'], ['Colby', 'Conspiracy', '(', 'Colby', 'Agency', ')'], ['The', 'Psychology', 'of', 'Proof', ':', 'Deductive', 'Reasoning', 'in', 'Human', 'Thinking'], ['The', 'Catcher', 'in', 'the', 'Rye'], ['Bait', 'and', 'Switch', ':', 'The', '(', 'Futile', ')', 'Pursuit', 'of', 'the', 'American', 'Dream'], ['Opening', 'Combination', 'Padlocks', ':', 'No', 'Tools', ',', 'No', 'Problem'], ['A', 'Little', 'History', 'of', 'the', 'World', '(', 'Little', 'Histories', ')'], ['Hour', 'Game', '(', 'King', '&', 'Maxwell', ')'], ['Faith', 'is', 'a', 'Verb'], ['Furry', 'Logic', ':', 'A', 'Guide', 'to', 'Life', "'s", 'Little', 'Challenges'], ['Acts', 'of', 'War', ':', 'Behavior', 'of', 'Men', 'in', 'Battle'], ['Temple', 'to', 'the', 'Wind', ':', 'The', 'Story', 'of', 'America', "'s", 'Greatest', 'Naval', 'Architect', 'and', 'His', 'Masterpiece', ',', 'Reliance'], ['The', 'Star', 'Wars', 'Poster', 'Book'], ['Photoshop', 'for', 'Nature', 'Photographers', ':', 'A', 'Workshop', 'in', 'a', 'Book'], ['The', 'Basic', 'Works', 'of', 'Aristotle', '(', 'Modern', 'Library', 'Classics', ')'], ['The', 'Pterosaurs', ':', 'From', 'Deep', 'Time'], ['Straight', 'Man', ':', 'A', 'Novel'], ['Lipstick', "'s", 'Legacy']]

# %%
mydata = data[['product_id', 'product_parent', 'product_title', 'review_body', 'star_rating']]
mydata.shape
mydata
# Out:
#          product_id product_parent  \
# 1        0385730586      122662979
# 2        0811828964       56191234
# 3        1844161560      253182049
# 4        0373836635      348672532
# 5        0262181533      598678717
# ...             ...            ...
# 3105366  0471114251      574261099
# 3105367  089145537X      836948045
# 3105368  047194128X      377091465
# 3105369  0521314925      980601331
# 3105370  0870210092      442607382
#
#                                              product_title  \
# 1               Sisterhood of the Traveling Pants (Book 1)
# 2            The Bad Girl's Guide to Getting What You Want
# 3                   Eisenhorn (A Warhammer 40,000 Omnibus)
# 4                          Colby Conspiracy (Colby Agency)
# 5        The Psychology of Proof: Deductive Reasoning i...
# ...                                                    ...
# 3105366  Bitter Winds: A Memoir of My Years in China's ...
# 3105367  The Collector's Guide to Harker Pottery U.S.A....
# 3105368                       Object-Oriented Type Systems
# 3105369  Invention and Evolution:Design in Nature and E...
# 3105370  Arming and Fitting of English Ships of War, 16...
#
#                                                review_body star_rating
# 1        this boook was a great one that you could lear...           4
# 2        If you are looking for something to stimulate ...           3
# 3        never read it-a young relative idicated he lik...           4
# 4        Though she is honored to be Chicago Woman of t...           5
# 5        Review based on a cursory examination by Unive...           4
# ...                                                    ...         ...
# 3105366  &quot;Bitter Winds&quot; is at once fascinatin...           4
# 3105367  OK, I'm biased. My mother wrote this one. Many...           5
# 3105368  The best (and possibly only) book I've seen on...           4
# 3105369  This is a beautiful book.  French talks about ...           5
# 3105370  Nice diags, lucid explanations of rigging, gun...           4
#
# [3105370 rows x 5 columns]

# %%
import re
import string
from gensim.parsing.preprocessing import remove_stopwords

def clean_text(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    text = remove_stopwords(text)
    return text

# %%
# Applying text cleaning lowercasing and removing punctuation to Book Titles.

# mydata['product_title'] = mydata['product_title'].apply(clean_text)

display(mydata.head())

#mydata['product_title'].apply(psy).sum()
# Out:
#    product_id product_parent  \
# 1  0385730586      122662979
# 2  0811828964       56191234
# 3  1844161560      253182049
# 4  0373836635      348672532
# 5  0262181533      598678717
#
#                                        product_title  \
# 1                    sisterhood traveling pants book
# 2                       bad girls guide getting want
# 3                        eisenhorn warhammer omnibus
# 4                      colby conspiracy colby agency
# 5  psychology proof deductive reasoning human thi...
#
#                                          review_body star_rating
# 1  this boook was a great one that you could lear...           4
# 2  If you are looking for something to stimulate ...           3
# 3  never read it-a young relative idicated he lik...           4
# 4  Though she is honored to be Chicago Woman of t...           5
# 5  Review based on a cursory examination by Unive...           4

# %%
sozluk3 = {'Politics': 0}


def pols(title):
    if title in sozluk3.keys():
        sozluk3.values = 1
    else:
        sozluk3.values = 0
    return sozluk3.values

mydata['product_title'].apply(pols).sum()

sozluk3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17720/2466688032.py in <module>
#       9     return sozluk3.values
#      10
# ---> 11 mydata['product_title'].apply(pols).sum()
#      12
#      13 sozluk3
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# C:\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# C:\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# C:\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_17720/2466688032.py in pols(title)
#       6         sozluk3.values = 1
#       7     else:
# ----> 8         sozluk3.values = 0
#       9     return sozluk3.values
#      10
#
# AttributeError: 'dict' object attribute 'values' is read-only

# %%
mydata.head()
# Out:
#    product_id product_parent  \
# 1  0385730586      122662979
# 2  0811828964       56191234
# 3  1844161560      253182049
# 4  0373836635      348672532
# 5  0262181533      598678717
#
#                                        product_title  \
# 1                    sisterhood traveling pants book
# 2                       bad girls guide getting want
# 3                        eisenhorn warhammer omnibus
# 4                      colby conspiracy colby agency
# 5  psychology proof deductive reasoning human thi...
#
#                                          review_body star_rating
# 1  this boook was a great one that you could lear...           4
# 2  If you are looking for something to stimulate ...           3
# 3  never read it-a young relative idicated he lik...           4
# 4  Though she is honored to be Chicago Woman of t...           5
# 5  Review based on a cursory examination by Unive...           4

# %%
# Bu sözlükte çalışmıyor.

sozluk = {'Psychology' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}

def psy(x):
    if x in sozluk.values():
        a = 1
    else:
        a = 0
    return a


# mydata.head()
# Out:
# 0

# %%
# len(pd.unique(mydata['product_id']))


# Bu ikisinin ayni cikmasi gerekmez mi??????????
# len(pd.unique(mydata['product_title']))
# len(pd.unique(data['product_parent']))

# def num(x):
  #  if x == 122518901:
   #     a = 1
    # else:
      #   a = 0
    # return a

# mydata['product_parent'].apply(num).sum()
# Out:
# 'Review based on a cursory examination by University of Phoenix students in Philosophy 251.  <br />We have found the book to be well organized, and detailed. The structure placed the information in an easy to read and presentable manner. <br />The use of strong and sound proofs by experiment and examples supported the overall logic of reasoning in a clear and concise manner. <br />We have found the book to be well thought out and laid out so the reader can learn and follow what is being explained. <br />'

# %%
# mydata['product_parent'] = mydata['product_parent'].astype('int')
# mydata['star_rating'] = mydata['star_rating'].astype('int') ########## ERROR

def psy(x):
    if 'psych' in x:
        a = 1
    else:
        a = 0
    return a

mydata['product_title'].apply(psy).sum()
# Out:
# 12979

# %%
# Number of unique values within a pandas column.
n = len(pd.unique(mydata['product_parent']))
p = len(pd.unique(mydata['product_id']))

print(n)
print(p)
# Out:
# 698251
# 779714

# %%
# Bu niye çalışmadı?
dict_psy = {'Psychology' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}

for i in mydata['product_title']:
    if i in dict_psy['Psychology']['key_word']:
        dict_psy['count'] = 1
    else:
        dict_psy['count'] = 0

print(dict_psy)

# Bu da çalışmadı?
dict_psych = {'Psychology' : 0}


if 'psych' in mydata['product_title']:
    dict_psych['Psychology'] += 1
else:
    dict_psych['Psychology'] = 0
        
print(dict_psych)
# Out:
# {'Psychology': {'key_word': ['psychology', 'psychological'], 'count': 0}, 'count': 0}

# %%
# Out:
# {'Psychology': 0}

# %%
dict_psy = {'Psychology' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}
dict_pols = {'Politics' : {'key_word' : ['politicial science', 'politics'], 'count' : 0}}
dict_soc = {'Sociology' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}
dict_anth = {'Anthropology' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}
dict_econ = {'Economy' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}

# %%
# Sözlük olmayınca her bir disiplin için ayrı bir liste. Kitap isimlerini listeye topluyorum.

# list_titles = mydata['product_title'].to_list()

# print(list_titles[:100])

# from collections import Counter

# list_psy = [i for i in list_titles if 'psych' in i]

psy_items = Counter(list_psy).keys()
print("No of unique items in the list are:", len(psy_items))
# Out:
# No of unique items in the list are: 4020

# %%
# dict_pols = {'Politics' : {'key_word' : ['politicial science', 'politics', 'international relations'], 'count' : 0}}

# dict_pols = {'Politics' : ['politicial science', 'politics', 'international relations']}  NOT_working

list_pols = [i for i in list_titles if ('politic' in i) or ('international relations' in i)]

pols_items = Counter(list_pols).keys()
print("No of unique items in the list are:", len(pols_items))

print(list_pols)
# Out:
# No of unique items in the list are: 4978
# ['attack messenger politicians turn media american political challenges', 'ezekiel option political thrillers option', 'unreasonable woman true story shrimpers politicos polluters fight seadrift texas', 'loyalty kingdom christ christian responsibility politics society', 'information american democracy technology evolution political power communication society politics', 'soul politics religious right secular left', 'dictatorships double standards rationalism reason politics', 'living hell true odyssey womans struggle islamic iran personal political forces', 'vaclav havel civic responsibility postmodern age century political thinkers', 'politically incorrect guide islam crusades', 'man house life political memoirs speaker tip oneill', 'unreasonable woman true story shrimpers politicos polluters fight seadrift texas', 'shrub short happy political life george w bush', 'instant expert collecting political memorabilia', 'slam dunks nobrainers language life media business politics like', 'politically incorrect guide islam crusades', 'human political education', 'right rock black rock coalition cultural politics race', 'visions politics vol renaissance virtues visions politics paperback', 'political theory international relations', 'conclave politics personalities process papal election', 'gods politics right gets wrong left doesnt', 'politically incorrect guide islam crusades', 'politically incorrect guide islam crusades', 'irony democracy uncommon introduction american politics', 'nourishing traditions cookbook challenges politically correct nutrition diet dictocrats', 'slam dunks nobrainers language life media business politics like', 'living hell true odyssey womans struggle islamic iran personal political forces', 'sikhs punjab unheard voices state guerilla violence politics contemporary asia', 'hamas political thought practice', 'political power corporate control new global politics corporate governance', 'unreasonable woman true story shrimpers politicos polluters fight seadrift texas', 'fulk nerra neoroman consul political biography angevin count', 'manufacturing consent political economy mass media', 'slam dunks nobrainers language life media business politics like', 'living hell true odyssey womans struggle islamic iran personal political forces', 'damned lies statistics untangling numbers media politicians activists', 'leo strauss politics american empire', 'politically incorrect guide islam crusades', 'affairs honor national politics new republic', 'great game politics effort present elementary human facts politics politicians political machines politics people ordeal selfgovernment america', 'america got right march military political supremacy', 'politics wellstone way elect progressive candidates win issues', 'politically incorrect guide islam crusades', 'slam dunks nobrainers language life media business politics like', 'living hell true odyssey womans struggle islamic iran personal political forces', 'soul politics religious right secular left', 'ladies gentlemen bronx burning baseball politics battle soul city', 'hermit peking hidden life sir edmund backhouse history politics', 'polish americans history community culture politics', 'ezekiel option political thrillers option', 'crimes logic exposing bogus arguments politicians priests journalists serial offenders', 'warrior politics leadership demands pagan ethos', 'politically incorrect guide islam crusades', 'attack messenger politicians turn media american political challenges', 'politicide ariel sharons war palestinians', 'manufacturing consent political economy mass media', 'winning political campaigns comprehensive guide electoral success', 'friendly advice future china suggestions political educational economic reforms survive century global competition', 'taking sides clashing views controversial political issues', 'exception rulers exposing oily politicians war profiteers media love', 'garlic oil politics food italy', 'band played politics people aids epidem ...

# %%
list_soc = [i for i in list_titles if 'sociol' in i]

soc_items = Counter(list_soc).keys()
print("No of unique items in the list are:", len(soc_items))

print(list_soc)
# Out:
# No of unique items in the list are: 392
# ['mapping social landscape readings sociology', 'sri aurobindo karl marx integral sociology dialectical sociology', 'status signals sociological study market competition', 'way schools work sociological analysis education edition', 'seeing classic contemporary crosscultural readings sociology sixth edition', 'sociology making sense social world', 'sociology edition', 'sociology global perspective infotrac', 'race ethnicity gender class sociology group conflict change sage masters modern social thought', 'sociology introduction', 'sociology', 'la razon populista seccion obras sociologia spanish edition', 'practical skeptic core concepts sociology', 'practical skeptic readings sociology', 'sociological imagination', 'annual editions sociology', 'classical sociological theory', 'sociology community collection readings new sociology library', 'sociology downtoearth approach edition', 'theories society foundations modern sociological theory', 'race ethnicity gender class sociology group conflict change sage masters modern social thought', 'race ethnicity gender class sociology group conflict change sage masters modern social thought', 'symbols selves social reality symbolic interactionist approach social psychology sociology', 'lucullus life international library sociology paperback', 'travels ernest crossing literarysociological divide ethnographic alternatives', 'race ethnicity gender class sociology group conflict change sage masters modern social thought', 'democracia en blanco el movimiento medico en mexico sociología y política spanish edition', 'english world sociolinguistic perspectives', 'sociology marriage family gender love property', 'race ethnicity gender class sociology group conflict change sage masters modern social thought', 'sociology housework', 'ghostly matters haunting sociological imagination', 'central eurasia global politics conflict security development international studies sociology social anthropology v', 'clep introductory sociology clep test preparation', 'method mess social science research international library sociology', 'outlines sociology lester f ward', 'empirical approaches sociology collection classic contemporary readings edition', 'claiming power doctorpatient talk oxford studies sociolinguistics', 'politeness universals language usage studies interactional sociolinguistics', 'seeing classic contemporary crosscultural readings sociology sixth edition', 'montesquieu rousseau forerunners sociology', 'asa guide graduate departments sociology guide graduate departments sociology', 'new directions military sociology', 'earth sociology introductory readings eleventh edition', 'language society introduction sociolinguistics', 'inequality power development issues political sociology', 'qualitative methodology sociology describing social world', 'social construction reality treatise sociology knowledge', 'future christianity historical sociological political theological perspectives new zealand atf', 'second thoughts seeing conventional wisdom sociological eye', 'sociology marriage family gender love property', 'functions social conflict examination concept social conflict use empirical sociological research', 'inequality power development issues political sociology', 'penguin dictionary sociology penguin dictionary', 'economy society outline interpretive sociology volume set', 'know steez ethnographic sociolinguistic study styleshifting black american speech community publication american dialect society', 'aim cognition sociolinguistic philosophy', 'criminology sociological introduction', 'introduction sociology', 'collective memory heritage sociology series', 'techniques teaching sociological concepts', 'sociology brief introduction reel society interactive movie cdrom powerweb', 'sociology brief introduction free esource cdrom free powerweb', 'reproduction mothering psychoanalysis sociology gender updated edition', 'essentials sociology downtoearth approach', 'keeping hands satan evangelical sc ...

# %%
list_econ = [i for i in list_titles if 'econo' in i]

econ_items = Counter(list_econ).keys()
print("No of unique items in the list are:", len(econ_items))

print(list_econ)
# Out:
# No of unique items in the list are: 3188
# ['end poverty economic possibilities time', 'coming generational storm need know americas economic future mit press', 'experience economy work theater business stage', 'freakonomics rogue economist explores hidden', 'common sense business starting operating growing small businessin economy', 'freakonomics rogue economist explores hidden', 'hydrogen economy', 'market god extreme capitalism market populism end economic democracy', 'microeconomics explore apply enhanced edition', 'parable pipeline build pipeline ongoing residual income new economy', 'freakonomics rogue economist explores hidden', 'economical writing', 'foundations microeconomics plus myeconlab rebate card edition', 'confessions economic hit man', 'study guide accompany financial accounting economic context edition', 'methods economic evaluation health care programmes', 'freakonomics rogue economist explores hidden', 'freakonomics rogue economist explores hidden', 'world economy trade finance economic applications printed access card', 'freakonomics rogue economist explores hidden', 'economics microfinance', 'eminent economists life philosophies', 'confessions economic hit man', 'shortchanged life debt fringe economy', 'manufacturing consent political economy mass media', 'confessions economic hit man', 'freakonomics rogue economist explores hidden', 'freakonomics rogue economist explores hidden', 'freakonomics rogue economist explores hidden', 'freakonomics rogue economist explores hidden', 'economic philosophic manuscripts communist manifesto great books philosophy', 'freakonomics rogue economist explores hidden', 'freakonomics rogue economist explores hidden', 'mapping security corporate security sourcebook todays global economy', 'freakonomics rogue economist explores hidden', 'microeconomics', 'market god extreme capitalism market populism end economic democracy', 'economic way thinking edition', 'sex drugs economics unconventional intro economics', 'mathematics economics edition', 'manufacturing consent political economy mass media', 'freakonomics rogue economist explores hidden', 'freakonomics rogue economist explores hidden', 'friendly advice future china suggestions political educational economic reforms survive century global competition', 'economic man feminist theory economics', 'macroeconomics myeconlab student access kit edition', 'freakonomics rogue economist explores hidden', 'freakonomics rogue economist explores hidden', 'freakonomics rogue economist explores hidden', 'freakonomics rogue economist explores hidden', 'basic economics citizens guide economy', 'said bloomberg economics columnist takes bonds banks budgets bubbles', 'principles microeconomics', 'washington connection world fascism political economy human rights volume', 'capitalist manifesto historic economic philosophic case laissezfaire', 'freakonomics rogue economist explores hidden', 'freakonomics rogue economist explores hidden', 'confessions economic hit man', 'ecoeconomy', 'abcs political economy modern approach', 'thank president bush reflections war terror defense family revival economy', 'environmental economics policy edition addisonwesley series economics', 'microeconomics today', 'freakonomics rogue economist explores hidden', 'flying engine bloomberg book master market economists', 'economics policymaking selected essays arthur m okun', 'confessions economic hit man', 'economics private public choice xtra cdrom infotrac college edition economics private public choice', 'capitalist manifesto historic economic philosophic case laissezfaire', 'capitalist manifesto historic economic philosophic case laissezfaire', 'john kenneth galbraith life politics economics', 'economics principles problems policies', 'principles microeconomics study guide edition', 'beating business cycle predict profit turning points economy', 'said bloomberg economics columnist takes bonds banks budgets bubbles', 'armchair economist economics everyday life', 'macroeconomics discoverecon online paul solm ...

# %%
list_anth = [i for i in list_titles if 'anthropo' in i]

anth_items = Counter(list_anth).keys()
print("No of unique items in the list are:", len(anth_items))

print(list_anth)
# Out:
# No of unique items in the list are: 584
# ['nest wind adventures anthropology tropical island second edition', 'introduction physical anthropology infotrac', 'cultural anthropology', 'control subversion gender relations tajikistan anthropology culture society', 'trail bones cases files forensic anthropologist', 'trail bones cases files forensic anthropologist', 'shamans religion anthropological exploration critical thinking', 'philosophical roots anthropology lecture notes', 'adaptation human behavior anthropological perspective evolutionary foundations human behavior series', 'annual editions physical anthropology', 'trail hare environment stress subarctic community library anthropology', 'annual editions anthropology', 'cultural anthropology', 'unsettled anthropology jews', 'cultural anthropology human challenge cdrom infotrac available titles cengagenow', 'bigfoot exposed anthropologist examines americas enduring legend', 'annual editions anthropology', 'anthropological theory introductory history', 'islam obscured rhetoric anthropological representation contemporary anthropology religion', 'business anthropology', 'anthropologists public sphere speaking war peace american power', 'anthropology religion magic witchcraft', 'malinowski odyssey anthropologist \x96', 'reimagining human theological anthropology response systemic evil', 'bone lady life forensic anthropologist', 'significant interpersonal professional commitments anthropology history anthropology', 'outline esoteric science cw classics anthroposophy', 'gnostic anthropology', 'peaceful jihad negotiating identity modernity muslim java contemporary anthropology religion', 'anthropologist mars seven paradoxical tales', 'dead men tell tales strange fascinating cases forensic anthropologist', 'central eurasia global politics conflict security development international studies sociology social anthropology v', 'reserve memories power past chilcotin community studies anthropology north american indians', 'anthroposophy everyday life practical training thoughtbrovercoming nervousnessbrfacing karmabrthe temperaments', 'visual anthropology photography research method', 'anthropology true love stories', 'faits et dires du mzab preface gast m societe detudes linguistiques et anthropologiques france', 'symbol privilege ritual context british royalty anthropology form meaning', 'mirror humanity concise introduction cultural anthropology', 'memory crimean tatars deportation return anthropology history critical imagination', 'lives dust water anthropology change resistance northwestern mexico', 'trading states oil rivers study political development eastern nigeria classics african anthropology', 'reader anthropology religion wiley blackwell anthologies social cultural anthropology', 'case valentin tomberg anthroposophy jesuitism', 'spirits resistance capitalist discipline suny series anthropology work', 'patients healers context culture exploration borderland anthropology medicine psychiatry comparative studies health systems medical care', 'indians pennsylvania anthropological series pennsylvania historical museum commission', 'cultural anthropology human challenge cdrom infotrac available titles cengagenow', 'living inside prison walls adjustment behavior university utah anthropological', 'social cultural anthropology short introduction', 'bigfoot exposed anthropologist examines americas enduring legend', 'threatening anthropology mccarthyism fbirsquos surveillance activist anthropologists', 'innocent anthropologist notes mud hut', 'annihilating difference anthropology genocide', 'chechnya life wartorn society california series public anthropology', 'bone woman forensic anthropologists search truth mass graves rwanda bosnia croatia kosovo', 'anthropology christian witness', 'anthropological insights missionaries', 'culture identity history theory practice psychological anthropology', 'unsettled anthropology jews', 'annual editions physical anthropology', 'anthropology american girl', 'racism genocide anthropology reich' ...
