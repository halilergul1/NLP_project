# %%
# Import the os module
import os

# Get the current working directory
cwd = os.getcwd()

# Print the current working directory
print("Current working directory: {0}".format(cwd))

# Print the type of the returned object
print("os.getcwd() returns an object of type: {0}".format(type(cwd)))
# Out:
# Current working directory: C:\Users\ibrah\Desktop\KoçUni\2ndSpring_Donemi_Dersler\CSSM 530\python
# os.getcwd() returns an object of type: <class 'str'>

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ibrah\\Desktop\\Koç Uni\\2. Spring Dönemi, Dersler\\CSSM 530\\python'

# %%
import pandas as pd
import numpy as np
from collections import Counter


df = pd.read_csv('amazon_reviews_us_Books_v1_02.tsv', sep='\t', header=None, on_bad_lines='skip')

print(df.head())
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (1,4,7,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             0            1               2           3               4   \
# 0  marketplace  customer_id       review_id  product_id  product_parent
# 1           US     12076615   RQ58W7SMO911M  0385730586       122662979
# 2           US     12703090    RF6IUKMGL8SF  0811828964        56191234
# 3           US     12257412  R1DOSHH6AI622S  1844161560       253182049
# 4           US     50732546   RATOTLA3OF70O  0373836635       348672532
#
#                                               5                 6   \
# 0                                  product_title  product_category
# 1     Sisterhood of the Traveling Pants (Book 1)             Books
# 2  The Bad Girl's Guide to Getting What You Want             Books
# 3         Eisenhorn (A Warhammer 40,000 Omnibus)             Books
# 4                Colby Conspiracy (Colby Agency)             Books
#
#             7              8            9     10                 11  \
# 0  star_rating  helpful_votes  total_votes  vine  verified_purchase
# 1            4              2            3     N                  N
# 2            3              5            5     N                  N
# 3            4              1           22     N                  N
# 4            5              2            2     N                  N
#
#                                       12  \
# 0                        review_headline
# 1  this book was a great learning novel!
# 2                              Fun Fluff
# 3                    this isn't a review
# 4              fine author on her A-game
#
#                                                   13           14
# 0                                        review_body  review_date
# 1  this boook was a great one that you could lear...   2005-10-14
# 2  If you are looking for something to stimulate ...   2005-10-14
# 3  never read it-a young relative idicated he lik...   2005-10-14
# 4  Though she is honored to be Chicago Woman of t...   2005-10-14

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3105371 entries, 0 to 3105370
# Data columns (total 15 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   0       object
#  1   1       object
#  2   2       object
#  3   3       object
#  4   4       object
#  5   5       object
#  6   6       object
#  7   7       object
#  8   8       object
#  9   9       object
#  10  10      object
#  11  11      object
#  12  12      object
#  13  13      object
#  14  14      object
# dtypes: object(15)
# memory usage: 355.4+ MB

# %%
import numpy as np

df.isnull().sum().sum()
# Out:
# 199

# %%
df.columns = ['marketplace', 'customer_id', 'review_id', 'product_id', 'product_parent', 'product_title', 'product_category', 'star_rating', 
            'helpful_votes', 'total_votes', 'vine', 'verified_purchase', 'review_headline', 'review_body', 'review_date']

print(df.head())
# Out:
#    marketplace  customer_id       review_id  product_id  product_parent  \
# 0  marketplace  customer_id       review_id  product_id  product_parent
# 1           US     12076615   RQ58W7SMO911M  0385730586       122662979
# 2           US     12703090    RF6IUKMGL8SF  0811828964        56191234
# 3           US     12257412  R1DOSHH6AI622S  1844161560       253182049
# 4           US     50732546   RATOTLA3OF70O  0373836635       348672532
#
#                                    product_title  product_category  \
# 0                                  product_title  product_category
# 1     Sisterhood of the Traveling Pants (Book 1)             Books
# 2  The Bad Girl's Guide to Getting What You Want             Books
# 3         Eisenhorn (A Warhammer 40,000 Omnibus)             Books
# 4                Colby Conspiracy (Colby Agency)             Books
#
#    star_rating  helpful_votes  total_votes  vine  verified_purchase  \
# 0  star_rating  helpful_votes  total_votes  vine  verified_purchase
# 1            4              2            3     N                  N
# 2            3              5            5     N                  N
# 3            4              1           22     N                  N
# 4            5              2            2     N                  N
#
#                          review_headline  \
# 0                        review_headline
# 1  this book was a great learning novel!
# 2                              Fun Fluff
# 3                    this isn't a review
# 4              fine author on her A-game
#
#                                          review_body  review_date
# 0                                        review_body  review_date
# 1  this boook was a great one that you could lear...   2005-10-14
# 2  If you are looking for something to stimulate ...   2005-10-14
# 3  never read it-a young relative idicated he lik...   2005-10-14
# 4  Though she is honored to be Chicago Woman of t...   2005-10-14

# %%
data = pd.DataFrame(df)

# print(data.head())

# type(data)

# print(data)

data = df.iloc[1:, :]

# print(data)

from IPython.display import display

display(data.head())

# df['review_body'].isnull().sum()
# Out:
#   marketplace customer_id       review_id  product_id product_parent  \
# 1          US    12076615   RQ58W7SMO911M  0385730586      122662979
# 2          US    12703090    RF6IUKMGL8SF  0811828964       56191234
# 3          US    12257412  R1DOSHH6AI622S  1844161560      253182049
# 4          US    50732546   RATOTLA3OF70O  0373836635      348672532
# 5          US    51964897  R1TNWRKIVHVYOV  0262181533      598678717
#
#                                        product_title product_category  \
# 1         Sisterhood of the Traveling Pants (Book 1)            Books
# 2      The Bad Girl's Guide to Getting What You Want            Books
# 3             Eisenhorn (A Warhammer 40,000 Omnibus)            Books
# 4                    Colby Conspiracy (Colby Agency)            Books
# 5  The Psychology of Proof: Deductive Reasoning i...            Books
#
#   star_rating helpful_votes total_votes vine verified_purchase  \
# 1           4             2           3    N                 N
# 2           3             5           5    N                 N
# 3           4             1          22    N                 N
# 4           5             2           2    N                 N
# 5           4             0           2    N                 N
#
#                          review_headline  \
# 1  this book was a great learning novel!
# 2                              Fun Fluff
# 3                    this isn't a review
# 4              fine author on her A-game
# 5          Execellent cursor examination
#
#                                          review_body review_date
# 1  this boook was a great one that you could lear...  2005-10-14
# 2  If you are looking for something to stimulate ...  2005-10-14
# 3  never read it-a young relative idicated he lik...  2005-10-14
# 4  Though she is honored to be Chicago Woman of t...  2005-10-14
# 5  Review based on a cursory examination by Unive...  2005-10-14

# %%
import matplotlib.pyplot as plt

# %%
def len_of_str(x):
    if type(x) != float:
        leng = len(x)
    else:
        leng = 0
    return leng

plt.hist(data['review_body'].apply(len_of_str), range=[0, 1000], facecolor='gray', align='mid')
# Out:
# (array([ 59784., 214333., 323041., 347699., 323746., 283348., 233594.,
#         189516., 156500., 130523.]),
#  array([   0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,  800.,
#          900., 1000.]),
#  <BarContainer object of 10 artists>)

# %%
sozluk = {'Psychology' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}
sozluk2 = {'Psychology' : 0}

sozluk['Psychology']
def psy(x):
    if 'psych' in x.lower():
        a = 1
    else:
        a = 0
    return a

data['product_title'].apply(psy).sum()
# Out:
# 12983

# %%
list_of_titles = data['product_title'].to_list()

# print('List of Names: ', list_of_titles)

list_of_titles


from collections import Counter
# counts = Counter(list_of_titles)
# print(counts)

def soc(x):
    if 'sociology' in x.lower():
        a = 1
    else: 
        a = 0
    return a




data['product_title'].apply(soc).sum()
# Out:
# 455

# %%
# from nltk.tokenize import word_tokenize


# tokenized_sents = [word_tokenize(i) for i in list_of_titles]

# print(type(tokenized_sents))

# print(f'"Psychology" appears {counts["Psychology"]} time(s)')


# print(tokenized_sents[1:20])

# %%
mydata = data[['product_id', 'product_parent', 'product_title', 'review_body', 'star_rating', 'review_date']]
mydata.shape
mydata

pd.to_pickle(mydata,"originaldata.pkl")

# %%
import re
import string
from gensim.parsing.preprocessing import remove_stopwords

def clean_text(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    text = remove_stopwords(text)
    return text

# %%
# Applying text cleaning lowercasing and removing punctuation to Book Titles.

mydata['product_title'] = mydata['product_title'].apply(clean_text)

display(mydata.head())

#mydata['product_title'].apply(psy).sum()
# Out:
# C:\Users\ibrah\AppData\Local\Temp/ipykernel_25932/1450309328.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydata['product_title'] = mydata['product_title'].apply(clean_text)
#    product_id product_parent  \
# 1  0385730586      122662979
# 2  0811828964       56191234
# 3  1844161560      253182049
# 4  0373836635      348672532
# 5  0262181533      598678717
#
#                                        product_title  \
# 1                    sisterhood traveling pants book
# 2                       bad girls guide getting want
# 3                        eisenhorn warhammer omnibus
# 4                      colby conspiracy colby agency
# 5  psychology proof deductive reasoning human thi...
#
#                                          review_body star_rating review_date
# 1  this boook was a great one that you could lear...           4  2005-10-14
# 2  If you are looking for something to stimulate ...           3  2005-10-14
# 3  never read it-a young relative idicated he lik...           4  2005-10-14
# 4  Though she is honored to be Chicago Woman of t...           5  2005-10-14
# 5  Review based on a cursory examination by Unive...           4  2005-10-14

# %%
sozluk3 = {'Politics': 0}


def pols(title):
    if title in sozluk3.keys():
        sozluk3.values = 1
    else:
        sozluk3.values = 0
    return sozluk3.values

# Not working

# %%
mydata.head()
# Out:
#    product_id product_parent  \
# 1  0385730586      122662979
# 2  0811828964       56191234
# 3  1844161560      253182049
# 4  0373836635      348672532
# 5  0262181533      598678717
#
#                                        product_title  \
# 1                    sisterhood traveling pants book
# 2                       bad girls guide getting want
# 3                        eisenhorn warhammer omnibus
# 4                      colby conspiracy colby agency
# 5  psychology proof deductive reasoning human thi...
#
#                                          review_body star_rating review_date
# 1  this boook was a great one that you could lear...           4  2005-10-14
# 2  If you are looking for something to stimulate ...           3  2005-10-14
# 3  never read it-a young relative idicated he lik...           4  2005-10-14
# 4  Though she is honored to be Chicago Woman of t...           5  2005-10-14
# 5  Review based on a cursory examination by Unive...           4  2005-10-14

# %%
# Bu sözlükte çalışmıyor.

sozluk = {'Psychology' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}

def psy(x):
    if x in sozluk.values():
        a = 1
    else:
        a = 0
    return a


# mydata.head()

# %%
# len(pd.unique(mydata['product_id']))


# Bu ikisinin ayni cikmasi gerekmez mi??????????
# len(pd.unique(mydata['product_title']))
# len(pd.unique(data['product_parent']))

def num(x):
    if x == 122518901:
        print(x)
    else:
        print('not found')
    return x

#

# %%
# mydata['product_parent'] = mydata['product_parent'].astype('int')
# mydata['star_rating'] = mydata['star_rating'].astype('int') ########## ERROR

def psy(x):
    if 'psych' in x:
        a = 1
    else:
        a = 0
    return a

mydata['product_title'].apply(psy).sum()
# Out:
# 12979

# %%
# Number of unique values within a pandas column.
n = len(pd.unique(mydata['product_parent']))
p = len(pd.unique(mydata['product_id']))

print(n)
print(p)
# Out:
# 698251
# 779714

# %%
# Bu niye çalışmadı?
dict_psy = {'Psychology' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}

for i in mydata['product_title']:
    if i in dict_psy['Psychology']['key_word']:
        dict_psy['count'] = 1
    else:
        dict_psy['count'] = 0

print(dict_psy)

# Bu da çalışmadı?
dict_psych = {'Psychology' : 0}


if 'psych' in mydata['product_title']:
    dict_psych['Psychology'] += 1
else:
    dict_psych['Psychology'] = 0
        
print(dict_psych)
# Out:
# {'Psychology': {'key_word': ['psychology', 'psychological'], 'count': 0}, 'count': 0}
# {'Psychology': 0}

# %%
dict_psy = {'Psychology' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}
dict_pols = {'Politics' : {'key_word' : ['politicial science', 'politics'], 'count' : 0}}
dict_soc = {'Sociology' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}
dict_anth = {'Anthropology' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}
dict_econ = {'Economy' : {'key_word' : ['psychology', 'psychological'], 'count' : 0}}

# %%
# Sözlük olmayınca her bir disiplin için ayrı bir liste. Kitap isimlerini listeye topluyorum.

list_titles = mydata['product_title'].to_list()

# print(list_titles[:100])

from collections import Counter

list_psy = [i for i in list_titles if 'psych' in i]

psy_items = Counter(list_psy).keys()
print("No of unique items in the list are:", len(psy_items))
# Out:
# No of unique items in the list are: 4020

# %%
# dict_pols = {'Politics' : {'key_word' : ['politicial science', 'politics', 'international relations'], 'count' : 0}}

# dict_pols = {'Politics' : ['politicial science', 'politics', 'international relations']}  NOT_working

list_pols = [i for i in list_titles if ('politic' in i) or ('international relations' in i)]

pols_items = Counter(list_pols).keys()
print("No of unique items in the list are:", len(pols_items))

# print(list_pols)
# Out:
# No of unique items in the list are: 4978

# %%
list_soc = [i for i in list_titles if 'sociol' in i]

soc_items = Counter(list_soc).keys()
print("No of unique items in the list are:", len(soc_items))

# print(list_soc)
# Out:
# No of unique items in the list are: 392

# %%
list_econ = [i for i in list_titles if 'econo' in i]

econ_items = Counter(list_econ).keys()
print("No of unique items in the list are:", len(econ_items))

# print(list_econ)
# Out:
# No of unique items in the list are: 3188

# %%
list_anth = [i for i in list_titles if 'anthropo' in i]

anth_items = Counter(list_anth).keys()
print("No of unique items in the list are:", len(anth_items))

# print(list_anth)
# Out:
# No of unique items in the list are: 584

# %%
# New COLUMN: Discipline
# mydata['discipline'] = ['psychology' if 'psych' in i else "other" for i in mydata['product_title']]



discipline = []

for row in mydata['product_title']:
    if 'psychol' in row:
        discipline.append('psychology')
    elif ('sociolo' in row) or ('social theory' in row) or ('gender' in row) or ('racism' in row) or ('social movement' in row) or ('social problems' in row) or ('social work' in row):
        discipline.append('sociology')
    elif ('politic' in row) or ('international relations' in row) or ('administration' in row):
        discipline.append('politics')
    elif ('econo' in row) or ('financ' in row):
        discipline.append('economy')
    elif 'anthropo' in row:
        discipline.append('anthropology')
    else:
        discipline.append('other')

        
mydata['discipline'] = discipline

print(mydata.head())
# Out:
#    product_id product_parent  \
# 1  0385730586      122662979
# 2  0811828964       56191234
# 3  1844161560      253182049
# 4  0373836635      348672532
# 5  0262181533      598678717
#
#                                        product_title  \
# 1                    sisterhood traveling pants book
# 2                       bad girls guide getting want
# 3                        eisenhorn warhammer omnibus
# 4                      colby conspiracy colby agency
# 5  psychology proof deductive reasoning human thi...
#
#                                          review_body star_rating review_date  \
# 1  this boook was a great one that you could lear...           4  2005-10-14
# 2  If you are looking for something to stimulate ...           3  2005-10-14
# 3  never read it-a young relative idicated he lik...           4  2005-10-14
# 4  Though she is honored to be Chicago Woman of t...           5  2005-10-14
# 5  Review based on a cursory examination by Unive...           4  2005-10-14
#
#    discipline
# 1       other
# 2       other
# 3       other
# 4       other
# 5  psychology
# C:\Users\ibrah\AppData\Local\Temp/ipykernel_25932/2710325467.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydata['discipline'] = discipline

# %%
mydata.head()

# mydata['discipline'].unique()

# mydata['discipline'].value_counts().plot.bar()

gk = mydata.groupby('discipline')

gk.first()

gk.get_group('psychology')

mydata.groupby(['product_id']).count()
# Out:
#             product_parent  product_title  review_body  star_rating  \
# product_id
# 0000000078               2              2            2            2
# 0000000116               1              1            1            1
# 0000000868               1              1            1            1
# 0000020214               1              1            1            1
# 0000024341               1              1            1            1
# ...                    ...            ...          ...          ...
# B003NHR7GC               1              1            1            1
# B00731BVMU               1              1            1            1
# B0083TTJPC               1              1            1            1
# B008GPOJ1C               1              1            1            1
# B008W3IU6I               1              1            1            1
#
#             review_date  discipline
# product_id
# 0000000078            2           2
# 0000000116            1           1
# 0000000868            1           1
# 0000020214            1           1
# 0000024341            1           1
# ...                 ...         ...
# B003NHR7GC            1           1
# B00731BVMU            1           1
# B0083TTJPC            1           1
# B008GPOJ1C            1           1
# B008W3IU6I            1           1
#
# [779714 rows x 6 columns]

# %%
n = len(pd.unique(mydata['product_parent']))

print("No.of.unique books :", 
      n)

y = len(pd.unique(mydata['product_id']))

print("No.of.unique books :", 
      y)
# Out:
# No.of.unique books : 698251
# No.of.unique books : 779714

# %%
# Creating a New DataFrame

dfbooks = mydata[mydata['discipline'] != 'other']

dfbooks.head()

dfbooks['discipline'].value_counts().plot.bar()

n = len(pd.unique(dfbooks['product_id']))
  
print("No.of.unique books :", n)

dfbooks.head()
# Out:
# No.of.unique books : 15418
#      product_id product_parent  \
# 5    0262181533      598678717
# 46   1594200459      697870179
# 86   0742538168      339619920
# 138  0262612089      733918058
# 205  0521832357       82232603
#
#                                          product_title  \
# 5    psychology proof deductive reasoning human thi...
# 46             end poverty economic possibilities time
# 86   attack messenger politicians turn media americ...
# 138  coming generational storm need know americas e...
# 205  c design patterns derivatives pricing mathemat...
#
#                                            review_body star_rating  \
# 5    Review based on a cursory examination by Unive...           4
# 46   ALthough he is correct that the IMF and World ...           3
# 86   While I don't always agree with his TV analysi...           2
# 138  Since the 1992 presidential run of H. Ross Per...           4
# 205  In terms of programming concepts and OOP desig...           5
#
#     review_date  discipline
# 5    2005-10-14  psychology
# 46   2005-10-14     economy
# 86   2005-10-14    politics
# 138  2005-10-14     economy
# 205  2005-10-14     economy

# %%
(dfbooks.groupby('discipline')
   ['product_parent'].nunique()
   .plot.bar())
# Out:
# <AxesSubplot:xlabel='discipline'>

# %%
(dfbooks.groupby('discipline') ['product_parent'].nunique().sum())
# Out:
# 14401

# %%
dfbooks.reset_index(inplace = True, drop = True) # resetting index values
dfbooks.head()

# print(dfbooks.iloc[10001]['review_body']) # to look a certain cell
# Out:
#    product_id product_parent  \
# 0  0262181533      598678717
# 1  1594200459      697870179
# 2  0742538168      339619920
# 3  0262612089      733918058
# 4  0521832357       82232603
#
#                                        product_title  \
# 0  psychology proof deductive reasoning human thi...
# 1            end poverty economic possibilities time
# 2  attack messenger politicians turn media americ...
# 3  coming generational storm need know americas e...
# 4  c design patterns derivatives pricing mathemat...
#
#                                          review_body star_rating review_date  \
# 0  Review based on a cursory examination by Unive...           4  2005-10-14
# 1  ALthough he is correct that the IMF and World ...           3  2005-10-14
# 2  While I don't always agree with his TV analysi...           2  2005-10-14
# 3  Since the 1992 presidential run of H. Ross Per...           4  2005-10-14
# 4  In terms of programming concepts and OOP desig...           5  2005-10-14
#
#    discipline
# 0  psychology
# 1     economy
# 2    politics
# 3     economy
# 4     economy

# %%
dfbooks['star_rating'].value_counts()

dfbooks['product_parent'].value_counts()

dfbooks['product_title'].nunique()
# Out:
# 16827

# %%
import pickle
pd.to_pickle(dfbooks,"data.pkl")

# %%
# print(dfbooks.iloc[9000]['review_body'])

dfbooks['review_body'].mean(len())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5136/2481911503.py in <module>
#       1 # print(dfbooks.iloc[9000]['review_body'])
#       2
# ----> 3 dfbooks['review_body'].mean(len())
#
# TypeError: len() takes exactly one argument (0 given)

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

# %%
import pandas as pd
data = pd.read_pickle("originaldata.pkl")
doc = list(nlp.pipe(data['product_title']))

# %%
# dfbooks = pd.read_pickle("data.pkl")

dfbooks.head()

# %%
from collections import Counter
print(Counter(dfbooks['product_title']).most_common(10))

print(Counter(dfbooks['product_title']).most_common(10))
# Out:
# [('freakonomics rogue economist explores hidden', 497), ('shut sing elites hollywood politics subverting america', 244), ('confessions economic hit man', 223), ('disappearance universe straight talk illusions past lives religion sex politics miracles forgiveness', 216), ('awaken giant immediate control mental emotional physical financial destiny', 167), ('american dynasty aristocracy fortune politics deceit house bush', 151), ('jihad political thrillers series', 147), ('new pearl harbor disturbing questions bush administration', 147), ('gods politics right gets wrong left doesnt', 138), ('rich dads cashflow quadrant rich dads guide financial freedom', 138)]
# [('freakonomics rogue economist explores hidden', 497), ('shut sing elites hollywood politics subverting america', 244), ('confessions economic hit man', 223), ('disappearance universe straight talk illusions past lives religion sex politics miracles forgiveness', 216), ('awaken giant immediate control mental emotional physical financial destiny', 167), ('american dynasty aristocracy fortune politics deceit house bush', 151), ('jihad political thrillers series', 147), ('new pearl harbor disturbing questions bush administration', 147), ('gods politics right gets wrong left doesnt', 138), ('rich dads cashflow quadrant rich dads guide financial freedom', 138)]

# %%
# Seperate dataframes for EDA
df_soc = dfbooks[dfbooks['discipline'] == 'sociology']
df_psy = dfbooks[dfbooks['discipline'] == 'psychology']
df_pols = dfbooks[dfbooks['discipline'] == 'politics']
df_econ = dfbooks[dfbooks['discipline'] == 'economy']
df_anth = dfbooks[dfbooks['discipline'] == 'anthropology']

# %%
print(Counter(df_soc['product_title']).most_common(100))
df_soc.head()
# Out:
# [('man queen science genderbending transsexualism', 79), ('end racism principles multiracial society', 63), ('shes life genders', 51), ('clep introductory sociology clep test preparation', 48), ('everyday racism book americans', 41), ('kinder gentler military americas genderneutral fighting force win wars lisa drew books', 41), ('killing rage ending racism owl book', 19), ('long prison journey leslie van houten life cult northeastern series gender crime law', 17), ('good news women biblical picture gender equality', 13), ('race religion racism vol bold encounter division church', 13), ('gender outlaw men women rest', 13), ('women dont ask negotiation gender divide', 13), ('gender knot unraveling patriarchal legacy', 12), ('gendersell sell opposite sex', 12), ('sexing body gender politics construction sexuality', 11), ('alice genderland crossdresser comes age', 11), ('gendered lives communication gender culture infotrac wadsworth series speech communication', 11), ('unbending gender family work conflict', 11), ('race class gender united states integrated study', 10), ('gender matters parents teachers need know emerging science sex differences', 10), ('transgender warriors making history joan arc dennis rodman', 10), ('social construction reality treatise sociology knowledge', 10), ('ego trips big book racism', 10), ('gay new york gender urban culture making gay male world', 10), ('journey software professional sociology software development', 10), ('gender trouble feminism subversion identity', 10), ('darwin hitler evolutionary ethics eugenics racism germany', 9), ('chasing gender dream', 9), ('defensive racism unapologetic examination racial differences', 9), ('quiet desperation understanding challenge samegender attraction', 9), ('pretty punk girls gender resistance boys subculture', 9), ('difference gender myths hurting relationships children jobs', 9), ('uninvited dilemma question gender', 9), ('blood biblical answer racism', 8), ('gender inclusive game design expanding market advances graphics game development series', 8), ('men women chain saws gender modern horror film', 8), ('sociology philosophies global theory intellectual change', 8), ('uprooting racism white people work racial justice', 8), ('pomosexuals challenging assumptions gender sexuality', 8), ('island race englishness empire gender eighteenth century', 8), ('race mind race iq racisms', 8), ('anna worlds desire chicago series sexuality gender culture', 8), ('meet beatles cultural history band shook youth gender world', 7), ('evolutions rainbow diversity gender sexuality nature people', 7), ('feminine endings music gender sexuality', 7), ('economy society outline interpretive sociology volume set', 7), ('introduction sociology', 7), ('wimp factor gender gaps holy wars politics anxious masculinity', 7), ('sacred canopy elements sociological theory religion', 7), ('reorienting economics economics social theory', 7), ('manliness civilization cultural history gender race united states women culture society', 7), ('race class gender diverse society textreader', 7), ('woman skeptics guide gender', 7), ('progressive muslims justice gender pluralism', 7), ('women gender islam historical roots modern debate', 7), ('iceman inheritance prehistoric sources western mans racism sexism aggression', 7), ('race ethnicity gender class sociology group conflict change sage masters modern social thought', 6), ('sociology', 6), ('socialism economic sociological analysis', 6), ('gender jim crow women politics white supremacy north carolina gender american culture', 6), ('constructing little house gender culture laura ingalls wilder', 6), ('gender trial sexual stereotypes worklife balance legal workplace', 6), ('letters divide friends explore racism friendship faith', 6), ('invitation sociology humanistic perspective', 6), ('suicide study sociology', 6), ('gender workbook real man real woman real entirely', 6), ('theology social theory secular reason signposts theology ser', 6), ('ge ...
#      product_id product_parent  \
# 45   0072878991      507793957
# 96   0872864499      289468524
# 156  0813536170      910849218
# 193  0745321674      121271872
# 207  0465077145      712396982
#
#                                          product_title  \
# 45         mapping social landscape readings sociology
# 96   heart whiteness confronting race racism white ...
# 156                               einstein race racism
# 193  control subversion gender relations tajikistan...
# 207  sexing body gender politics construction sexua...
#
#                                            review_body star_rating  \
# 45   very happy with this purchase. book was practi...           5
# 96   Review of The Heart of Whiteness<br /><br />Fo...           5
# 156  This book is a timely, fascinating and importa...           5
# 193  This book develops a clear picture of the soci...           4
# 207  Anne Fausto-Sterling's account of all genders ...           5
#
#     review_date discipline
# 45   2005-10-12  sociology
# 96   2005-10-11  sociology
# 156  2005-10-09  sociology
# 193  2005-10-08  sociology
# 207  2005-10-07  sociology

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english')
data_cv = cv.fit_transform(df_soc.product_title)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_dtm.index = df_soc.index
data_dtm
# Out:
#        ableism  abolitionism  abolitionist  aboriginal  abortion  abuse  \
# 45           0             0             0           0         0      0
# 96           0             0             0           0         0      0
# 156          0             0             0           0         0      0
# 193          0             0             0           0         0      0
# 207          0             0             0           0         0      0
# ...        ...           ...           ...         ...       ...    ...
# 42150        0             0             0           0         0      0
# 42155        0             0             0           0         0      0
# 42171        0             0             0           0         0      0
# 42178        0             0             0           0         0      0
# 42215        0             0             0           0         0      0
#
#        academe  academic  access  account  ...  yin  york  young  youre  \
# 45           0         0       0        0  ...    0     0      0      0
# 96           0         0       0        0  ...    0     0      0      0
# 156          0         0       0        0  ...    0     0      0      0
# 193          0         0       0        0  ...    0     0      0      0
# 207          0         0       0        0  ...    0     0      0      0
# ...        ...       ...     ...      ...  ...  ...   ...    ...    ...
# 42150        0         0       0        0  ...    0     0      0      0
# 42155        0         0       0        0  ...    0     0      0      0
# 42171        0         0       0        0  ...    0     0      0      0
# 42178        0         0       0        0  ...    0     0      0      0
# 42215        0         0       0        0  ...    0     0      0      0
#
#        youth  yugoslav  yugoslavia  zealand  zero  zoroastrian
# 45         0         0           0        0     0            0
# 96         0         0           0        0     0            0
# 156        0         0           0        0     0            0
# 193        0         0           0        0     0            0
# 207        0         0           0        0     0            0
# ...      ...       ...         ...      ...   ...          ...
# 42150      0         0           0        0     0            0
# 42155      0         0           0        0     0            0
# 42171      0         0           0        0     0            0
# 42178      0         0           0        0     0            0
# 42215      0         0           0        0     0            0
#
# [2876 rows x 3022 columns]

# %%
# Find the top 30 words 
top_dict = {}
for c in data_dtm.columns:
    top = data_dtm[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index, top.values))

top_dict
# Out:
# {'ableism': [(2320, 1),
#   (417, 1),
#   (6009, 1),
#   (28669, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (45, 0),
#   (28474, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28511, 0),
#   (28473, 0),
#   (28759, 0),
#   (28316, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'abolitionism': [(10846, 1),
#   (45, 0),
#   (28669, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28473, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28441, 0),
#   (28759, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'abolitionist': [(11245, 1),
#   (28669, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (45, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28441, 0),
#   (28759, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'aboriginal': [(25983, 1),
#   (45, 0),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28205, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'abortion': [(17936, 1),
#   (1980, 1),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (45, 0),
#   (28210, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'abuse': [(5260, 1),
#   (37642, 1),
#   (4752, 1),
#   (5274, 1),
#   (6592, 1),
#   (4808, 1),
#   (14091, 1),
#   (33973, 1),
#   (29885, 1),
#   (5184, 1),
#   (28567, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28642, 0),
#   (28595, 0),
#   (28628, 0),
#   (28473, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28474, 0),
#   (45, 0),
#   (28441, 0),
#   (28302, 0)],
#  'academe': [(34579, 1),
#   (34752, 1),
#   (45, 0),
#   (28642, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28441, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28752, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'academic': [(5830, 1),
#   (31865, 1),
#   (33087, 1),
#   (29974, 1),
#   (28709, 0),
#   (28708, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28723, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28474, 0),
#   (28473, 0),
#   (28441, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'access': [(21512, 1),
#   (21923, 1),
#   (45, 0),
#   (28669, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28474, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28511, 0),
#   (28473, 0),
#   (28759, 0),
#   (28441, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'account': [(27620, 1),
#   (21857, 1),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28752, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (45, 0),
#   (28441, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'accountability': [(38975, 1),
#   (39218, 1),
#   (36089, 1),
#   (28595, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (45, 0),
#   (28628, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28642, 0),
#   (28430, 0),
#   (28717, 0),
#   (28415, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'accounting': [(38975, 1),
#   (39218, 1),
#   (36089, 1),
#   (28595, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (45, 0),
#   (28628, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28642, 0),
#   (28430, 0),
#   (28717, 0),
#   (28415, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'accounts': [(19312, 1),
#   (34797, 1),
#   (33101, 1),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (45, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28642, 0),
#   (28473, 0),
#   (28441, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'accuracy': [(13455, 1),
#   (12577, 1),
#   (17889, 1),
#   (22155, 1),
#   (34937, 1),
#   (23473, 1),
#   (37099, 1),
#   (28280, 0),
#   (28287, 0),
#   (28595, 0),
#   (28271, 0),
#   (28270, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28267, 0),
#   (28695, 0),
#   (28264, 0),
#   (28705, 0),
#   (28253, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28567, 0),
#   (28556, 0),
#   (28550, 0),
#   (28356, 0)],
#  'achievement': [(5359, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'act': [(15530, 1),
#   (40720, 1),
#   (11577, 1),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (45, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28642, 0),
#   (28473, 0),
#   (28441, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'action': [(4645, 1),
#   (40728, 1),
#   (37003, 1),
#   (28325, 1),
#   (45, 0),
#   (28628, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28473, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28474, 0),
#   (28430, 0),
#   (28441, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'active': [(27716, 1),
#   (45, 0),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28205, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'activism': [(491, 1),
#   (26067, 1),
#   (26010, 1),
#   (4893, 1),
#   (13856, 1),
#   (5421, 1),
#   (12978, 1),
#   (41876, 1),
#   (36183, 1),
#   (484, 1),
#   (3321, 1),
#   (1648, 1),
#   (28556, 0),
#   (28628, 0),
#   (28550, 0),
#   (28595, 0),
#   (28531, 0),
#   (28567, 0),
#   (28669, 0),
#   (28642, 0),
#   (28511, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28527, 0),
#   (45, 0)],
#  'activists': [(36755, 1),
#   (45, 0),
#   (28595, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28628, 0),
#   (28430, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28441, 0),
#   (28415, 0),
#   (28723, 0),
#   (28280, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'activities': [(31501, 1),
#   (3895, 1),
#   (13977, 1),
#   (40570, 1),
#   (45, 0),
#   (28595, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28642, 0),
#   (28628, 0),
#   (28717, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28474, 0),
#   (28473, 0),
#   (28441, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'acts': [(4246, 1),
#   (12743, 1),
#   (5106, 1),
#   (37811, 1),
#   (35374, 1),
#   (28595, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (45, 0),
#   (28628, 0),
#   (28473, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28474, 0),
#   (28430, 0),
#   (28441, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'actualizing': [(21192, 1),
#   (16667, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28473, 0),
#   (28430, 0),
#   (28723, 0),
#   (28415, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'ad': [(35697, 1),
#   (28441, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (45, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28628, 0),
#   (28430, 0),
#   (28201, 0),
#   (28415, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'adapted': [(17595, 1),
#   (45, 0),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (26939, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'addiction': [(29885, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'addictions': [(29885, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'adhd': [(16461, 1),
#   (45, 0),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'adjusting': [(39606, 1),
#   (45, 0),
#   (28628, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28430, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28441, 0),
#   (28415, 0),
#   (28723, 0),
#   (28280, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'administration': [(23300, 1),
#   (12152, 1),
#   (9737, 1),
#   (15426, 1),
#   (45, 0),
#   (28669, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28474, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28511, 0),
#   (28473, 0),
#   (28752, 0),
#   (28316, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'administrative': [(12152, 1),
#   (15426, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28473, 0),
#   (28430, 0),
#   (28723, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'administrators': [(35554, 1),
#   (45, 0),
#   (28628, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28430, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28441, 0),
#   (28415, 0),
#   (28201, 0),
#   (28280, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'admission': [(9385, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28441, 0),
#   (29365, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'adolescence': [(9974, 1),
#   (21087, 1),
#   (13888, 1),
#   (28642, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (45, 0),
#   (28511, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28669, 0),
#   (28474, 0),
#   (28759, 0),
#   (28473, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0),
#   (28270, 0)],
#  'adolescent': [(3216, 1),
#   (22608, 1),
#   (35572, 1),
#   (32401, 1),
#   (21283, 1),
#   (28708, 0),
#   (28705, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28709, 0),
#   (28628, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28473, 0),
#   (28382, 0),
#   (28430, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0)],
#  'adolescents': [(39315, 1),
#   (23529, 1),
#   (18495, 1),
#   (41645, 1),
#   (40594, 1),
#   (28642, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28474, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28511, 0),
#   (28441, 0),
#   (28473, 0),
#   (28752, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'adorno': [(17657, 1),
#   (45, 0),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (26939, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'adult': [(14006, 1),
#   (45, 0),
#   (28669, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28474, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28511, 0),
#   (28473, 0),
#   (28759, 0),
#   (28441, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0),
#   (28270, 0)],
#  'adultery': [(1980, 1),
#   (28441, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (45, 0),
#   (29348, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'adults': [(39242, 1),
#   (45, 0),
#   (28628, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28430, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28441, 0),
#   (28415, 0),
#   (28723, 0),
#   (28280, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'advances': [(7420, 1),
#   (7886, 1),
#   (12608, 1),
#   (8533, 1),
#   (35316, 1),
#   (2721, 1),
#   (39740, 1),
#   (7862, 1),
#   (7882, 1),
#   (5231, 1),
#   (12951, 1),
#   (28708, 0),
#   (28680, 0),
#   (28628, 0),
#   (28759, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28752, 0),
#   (28705, 0),
#   (28723, 0),
#   (28717, 0),
#   (28688, 0),
#   (28567, 0),
#   (28709, 0),
#   (28695, 0),
#   (28595, 0),
#   (45, 0),
#   (28556, 0),
#   (28356, 0)],
#  'advancing': [(22044, 1),
#   (23970, 1),
#   (23695, 1),
#   (23972, 1),
#   (23509, 1),
#   (28752, 0),
#   (28669, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28723, 0),
#   (28680, 0),
#   (28511, 0),
#   (28695, 0),
#   (28759, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28688, 0),
#   (45, 0),
#   (28767, 0),
#   (28319, 0),
#   (28264, 0)],
#  'adventism': [(39562, 1),
#   (45, 0),
#   (28628, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28430, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28441, 0),
#   (28415, 0),
#   (28723, 0),
#   (28280, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'adventures': [(12432, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28441, 0),
#   (29365, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'advertisements': [(19066, 1),
#   (45, 0),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'advertising': [(4543, 1),
#   (40991, 1),
#   (28642, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (45, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28473, 0),
#   (28415, 0),
#   (28430, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'aemilia': [(849, 1),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (45, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28205, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'aesthetics': [(21241, 1),
#   (28441, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28752, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'affinity': [(28321, 1),
#   (45, 0),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'affirmations': [(23757, 1),
#   (45, 0),
#   (28642, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28441, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28752, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'affluent': [(34324, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'africa': [(37103, 1),
#   (29992, 1),
#   (25560, 1),
#   (35535, 1),
#   (40530, 1),
#   (31028, 1),
#   (28567, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28595, 0),
#   (28430, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28441, 0),
#   (45, 0),
#   (28415, 0),
#   (28356, 0),
#   (28210, 0),
#   (28214, 0)],
#  'african': [(18015, 1),
#   (8299, 1),
#   (30090, 1),
#   (30093, 1),
#   (8913, 1),
#   (12713, 1),
#   (17793, 1),
#   (3782, 1),
#   (19109, 1),
#   (7697, 1),
#   (3678, 1),
#   (37103, 1),
#   (30525, 1),
#   (13242, 1),
#   (16128, 1),
#   (16216, 1),
#   (25560, 1),
#   (28356, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28302, 0),
#   (28287, 0),
#   (28688, 0),
#   (28319, 0),
#   (28695, 0),
#   (28280, 0),
#   (28705, 0),
#   (28708, 0)],
#  'africanamerican': [(34908, 1),
#   (45, 0),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'afroamerican': [(29081, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28752, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'afterlife': [(36928, 1),
#   (28441, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (45, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28628, 0),
#   (28430, 0),
#   (28723, 0),
#   (28415, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'age': [(20589, 1),
#   (525, 1),
#   (25172, 1),
#   (36755, 1),
#   (393, 1),
#   (31216, 1),
#   (36688, 1),
#   (41266, 1),
#   (25034, 1),
#   (724, 1),
#   (1422, 1),
#   (25721, 1),
#   (4318, 1),
#   (1979, 1),
#   (17595, 1),
#   (1929, 1),
#   (898, 1),
#   (225, 1),
#   (1907, 1),
#   (36183, 1),
#   (1871, 1),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (45, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28511, 0)],
#  'agency': [(34169, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (29348, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'agenda': [(25578, 1),
#   (9671, 1),
#   (28642, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28441, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28205, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'agendas': [(23714, 1),
#   (31689, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28675, 0),
#   (28669, 0),
#   (28473, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'ages': [(28224, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28302, 0),
#   (28214, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0),
#   (28270, 0)],
#  'aggression': [(31215, 1),
#   (15579, 1),
#   (26649, 1),
#   (36827, 1),
#   (16603, 1),
#   (20470, 1),
#   (13878, 1),
#   (28669, 0),
#   (28642, 0),
#   (28441, 0),
#   (28705, 0),
#   (28695, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28688, 0),
#   (28550, 0),
#   (28556, 0),
#   (28680, 0),
#   (28595, 0),
#   (28675, 0),
#   (28628, 0),
#   (28567, 0),
#   (45, 0),
#   (28709, 0),
#   (28287, 0),
#   (28210, 0),
#   (28214, 0)],
#  'aging': [(32548, 1),
#   (18125, 1),
#   (45, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28473, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'agroforestry': [(33857, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (29348, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'ahab': [(30933, 1),
#   (28441, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (29348, 0),
#   (28415, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'ahmad': [(12355, 1),
#   (45, 0),
#   (28669, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28473, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28441, 0),
#   (29365, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'aid': [(6097, 1),
#   (45, 0),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'aids': [(13856, 1),
#   (12978, 1),
#   (21281, 1),
#   (45, 0),
#   (28474, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28511, 0),
#   (28473, 0),
#   (28759, 0),
#   (28441, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'aires': [(10225, 1),
#   (9320, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'albanian': [(18851, 1),
#   (36345, 1),
#   (18136, 1),
#   (28441, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (45, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'alcohol': [(29694, 1),
#   (6592, 1),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (45, 0),
#   (28473, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28642, 0),
#   (28441, 0),
#   (28752, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'alcoholism': [(33780, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (29348, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'alice': [(724, 1),
#   (1907, 1),
#   (525, 1),
#   (393, 1),
#   (4318, 1),
#   (1422, 1),
#   (1929, 1),
#   (898, 1),
#   (1979, 1),
#   (225, 1),
#   (1871, 1),
#   (28705, 0),
#   (28675, 0),
#   (28752, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28723, 0),
#   (28680, 0),
#   (28717, 0),
#   (28688, 0),
#   (28550, 0),
#   (28695, 0),
#   (28709, 0),
#   (28708, 0),
#   (28556, 0),
#   (28474, 0),
#   (28531, 0)],
#  'alienation': [(27620, 1),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (45, 0),
#   (28205, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'allamerican': [(3431, 1),
#   (6136, 1),
#   (1716, 1),
#   (28669, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (45, 0),
#   (28474, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28511, 0),
#   (28473, 0),
#   (28759, 0),
#   (28316, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'allen': [(10150, 1),
#   (9073, 1),
#   (9109, 1),
#   (8722, 1),
#   (10509, 1),
#   (45, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28556, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28752, 0),
#   (28759, 0),
#   (28567, 0),
#   (28550, 0),
#   (28769, 0),
#   (28336, 0),
#   (28270, 0),
#   (28271, 0),
#   (28280, 0),
#   (28287, 0)],
#  'alliance': [(13584, 1),
#   (28669, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (45, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28441, 0),
#   (28759, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'alternative': [(6555, 1),
#   (18081, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'alternatives': [(6790, 1),
#   (4401, 1),
#   (1869, 1),
#   (45, 0),
#   (28628, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28473, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28430, 0),
#   (28441, 0),
#   (28752, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'althusser': [(20764, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28205, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'alvin': [(10905, 1),
#   (45, 0),
#   (28669, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28473, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28441, 0),
#   (28759, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'ambiguity': [(2484, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (29348, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'ambiguous': [(33864, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (29348, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'america': [(37352, 1),
#   (37339, 1),
#   (40435, 1),
#   (30124, 1),
#   (9598, 1),
#   (19617, 1),
#   (19718, 1),
#   (30414, 1),
#   (35316, 1),
#   (37453, 1),
#   (17228, 1),
#   (37399, 1),
#   (35376, 1),
#   (35432, 1),
#   (4785, 1),
#   (10049, 1),
#   (28166, 1),
#   (6953, 1),
#   (35515, 1),
#   (10166, 1),
#   (10225, 1),
#   (26213, 1),
#   (1305, 1),
#   (31049, 1),
#   (33085, 1),
#   (33072, 1),
#   (30081, 1),
#   (40233, 1),
#   (32998, 1),
#   (29694, 1)],
#  'american': [(21234, 2),
#   (21209, 2),
#   (3216, 2),
#   (28996, 2),
#   (21462, 2),
#   (21457, 2),
#   (38998, 1),
#   (25935, 1),
#   (5413, 1),
#   (33521, 1),
#   (28353, 1),
#   (23415, 1),
#   (5300, 1),
#   (12995, 1),
#   (19757, 1),
#   (20058, 1),
#   (25895, 1),
#   (30217, 1),
#   (37275, 1),
#   (33780, 1),
#   (7697, 1),
#   (19576, 1),
#   (33495, 1),
#   (40528, 1),
#   (30093, 1),
#   (10443, 1),
#   (20738, 1),
#   (16917, 1),
#   (28098, 1),
#   (20685, 1)],
#  'americanists': [(30124, 1),
#   (20159, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28669, 0),
#   (28642, 0),
#   (28441, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28473, 0),
#   (28430, 0),
#   (28723, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'americans': [(22265, 1),
#   (36790, 1),
#   (23436, 1),
#   (23446, 1),
#   (19164, 1),
#   (30372, 1),
#   (23521, 1),
#   (23534, 1),
#   (30186, 1),
#   (12646, 1),
#   (22301, 1),
#   (22290, 1),
#   (22280, 1),
#   (22262, 1),
#   (22167, 1),
#   (26666, 1),
#   (25247, 1),
#   (20790, 1),
#   (23751, 1),
#   (23434, 1),
#   (22617, 1),
#   (22641, 1),
#   (22906, 1),
#   (23020, 1),
#   (23120, 1),
#   (23178, 1),
#   (22948, 1),
#   (22937, 1),
#   (22916, 1),
#   (22915, 1)],
#  'americas': [(29148, 1),
#   (36071, 1),
#   (27513, 1),
#   (32725, 1),
#   (34315, 1),
#   (34305, 1),
#   (32846, 1),
#   (34291, 1),
#   (35862, 1),
#   (29606, 1),
#   (34280, 1),
#   (28709, 1),
#   (31186, 1),
#   (29734, 1),
#   (33049, 1),
#   (33050, 1),
#   (35631, 1),
#   (35599, 1),
#   (16872, 1),
#   (33988, 1),
#   (33265, 1),
#   (22566, 1),
#   (35156, 1),
#   (33947, 1),
#   (30030, 1),
#   (35170, 1),
#   (35190, 1),
#   (35466, 1),
#   (35214, 1),
#   (36033, 1)],
#  'amp': [(40895, 1),
#   (26194, 1),
#   (41253, 1),
#   (22829, 1),
#   (28567, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (45, 0),
#   (28441, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28595, 0),
#   (28415, 0),
#   (28430, 0),
#   (28280, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0)],
#  'analogies': [(32215, 1),
#   (45, 0),
#   (28642, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28441, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28752, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'analys': [(16408, 1),
#   (45, 0),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'analyses': [(12772, 1),
#   (45, 0),
#   (28669, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28474, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28511, 0),
#   (28473, 0),
#   (28759, 0),
#   (28441, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0),
#   (28270, 0)],
#  'analysis': [(9050, 1),
#   (28325, 1),
#   (30414, 1),
#   (33396, 1),
#   (28382, 1),
#   (5071, 1),
#   (5670, 1),
#   (10027, 1),
#   (26611, 1),
#   (27484, 1),
#   (29650, 1),
#   (32834, 1),
#   (37936, 1),
#   (31095, 1),
#   (15572, 1),
#   (38057, 1),
#   (31464, 1),
#   (19975, 1),
#   (7623, 1),
#   (41391, 1),
#   (4291, 1),
#   (40922, 1),
#   (35247, 1),
#   (40797, 1),
#   (20110, 1),
#   (34587, 1),
#   (35432, 1),
#   (18549, 1),
#   (345, 1),
#   (17228, 1)],
#  'analytical': [(29682, 1),
#   (45, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'analyzing': [(36951, 1),
#   (45, 0),
#   (28441, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28473, 0),
#   (28430, 0),
#   (28723, 0),
#   (28415, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'anaïs': [(40734, 1),
#   (24239, 1),
#   (45, 0),
#   (28595, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28441, 0),
#   (28430, 0),
#   (28723, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'ancien': [(41571, 1),
#   (28441, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (45, 0),
#   (28201, 0),
#   (28415, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'ancient': [(26489, 2),
#   (22542, 1),
#   (33546, 1),
#   (36942, 1),
#   (9036, 1),
#   (18458, 1),
#   (1387, 1),
#   (22541, 1),
#   (28642, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (45, 0),
#   (28474, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28511, 0),
#   (28430, 0),
#   (28473, 0),
#   (28316, 0)],
#  'andean': [(33391, 1),
#   (45, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28205, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'andor': [(4645, 1),
#   (45, 0),
#   (28642, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28441, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (26939, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'androgyny': [(3072, 1),
#   (30691, 1),
#   (45, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28430, 0),
#   (28441, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'angels': [(22016, 1),
#   (26040, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28675, 0),
#   (28669, 0),
#   (28752, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28473, 0),
#   (28441, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'anger': [(29004, 1),
#   (36558, 1),
#   (40449, 1),
#   (45, 0),
#   (28595, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28642, 0),
#   (28628, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28473, 0),
#   (28430, 0),
#   (28717, 0),
#   (28415, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'animal': [(37399, 1),
#   (36430, 1),
#   (28595, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28628, 0),
#   (28430, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28441, 0),
#   (45, 0),
#   (28723, 0),
#   (28415, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'anita': [(29729, 1),
#   (45, 0),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'ann': [(33047, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28205, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'anna': [(35872, 1),
#   (36357, 1),
#   (25528, 1),
#   (36463, 1),
#   (19033, 1),
#   (37765, 1),
#   (40225, 1),
#   (20947, 1),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28628, 0),
#   (28473, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28474, 0),
#   (45, 0),
#   (28441, 0),
#   (28430, 0),
#   (28214, 0)],
#  'annihilation': [(35699, 1),
#   (31706, 1),
#   (45, 0),
#   (28595, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28628, 0),
#   (28723, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28473, 0),
#   (28441, 0),
#   (28430, 0),
#   (28415, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'anniversary': [(9699, 1),
#   (45, 0),
#   (28669, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28473, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28441, 0),
#   (28210, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'annotated': [(6592, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28205, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'annual': [(1062, 1),
#   (45, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28441, 0),
#   (28205, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'answer': [(34171, 1),
#   (20026, 1),
#   (16893, 1),
#   (38393, 1),
#   (2619, 1),
#   (35996, 1),
#   (34104, 1),
#   (22899, 1),
#   (31098, 1),
#   (28628, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (45, 0),
#   (28642, 0),
#   (28669, 0),
#   (28527, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
# ...
#   (45, 0),
#   (29348, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'factory': [(35677, 1),
#   (29962, 1),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28473, 0),
#   (45, 0),
#   (28723, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'faculty': [(35554, 1),
#   (45, 0),
#   (28628, 0),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28430, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28441, 0),
#   (28415, 0),
#   (28201, 0),
#   (28280, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'failure': [(31138, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28205, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'fairy': [(9050, 1),
#   (34021, 1),
#   (45, 0),
#   (28669, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28511, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28527, 0),
#   (28474, 0),
#   (28214, 0),
#   (28473, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0),
#   (28270, 0),
#   (28271, 0)],
#  'faith': [(25622, 1),
#   (28173, 1),
#   (26329, 1),
#   (10286, 1),
#   (33072, 1),
#   (16859, 1),
#   (41280, 1),
#   (41275, 1),
#   (22597, 1),
#   (12359, 1),
#   (15692, 1),
#   (12361, 1),
#   (2162, 1),
#   (24591, 1),
#   (39975, 1),
#   (18245, 1),
#   (13321, 1),
#   (39305, 1),
#   (21961, 1),
#   (29343, 1),
#   (41876, 1),
#   (27369, 0),
#   (28695, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0)],
#  'fall': [(20110, 1),
#   (28767, 1),
#   (20001, 1),
#   (20164, 1),
#   (545, 1),
#   (19917, 1),
#   (28628, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28675, 0),
#   (28642, 0),
#   (28669, 0),
#   (28473, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28474, 0),
#   (28430, 0),
#   (28441, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0)],
#  'falun': [(32287, 1),
#   (45, 0),
#   (28642, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28441, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28752, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'familia': [(34536, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28752, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'families': [(8168, 1),
#   (36775, 1),
#   (3755, 1),
#   (38743, 1),
#   (2576, 1),
#   (25663, 1),
#   (17021, 1),
#   (9940, 1),
#   (9961, 1),
#   (9967, 1),
#   (32954, 1),
#   (15775, 1),
#   (28201, 1),
#   (27267, 0),
#   (28695, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28705, 0),
#   (28550, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (27074, 0)],
#  'family': [(6439, 2),
#   (35551, 1),
#   (36775, 1),
#   (3176, 1),
#   (9905, 1),
#   (32799, 1),
#   (38743, 1),
#   (30953, 1),
#   (9320, 1),
#   (34936, 1),
#   (38039, 1),
#   (36987, 1),
#   (29756, 1),
#   (2950, 1),
#   (26451, 1),
#   (37022, 1),
#   (30543, 1),
#   (5184, 1),
#   (16967, 1),
#   (25247, 1),
#   (2724, 1),
#   (5274, 1),
#   (10351, 1),
#   (29963, 1),
#   (5260, 1),
#   (36790, 1),
#   (10225, 1),
#   (29481, 1),
#   (36661, 1),
#   (4808, 1)],
#  'fantasies': [(37141, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28473, 0),
#   (28430, 0),
#   (28201, 0),
#   (28415, 0),
#   (28210, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'fantasy': [(9114, 1),
#   (45, 0),
#   (28669, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28474, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28511, 0),
#   (28473, 0),
#   (29365, 0),
#   (28441, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0),
#   (28270, 0)],
#  'farmers': [(26984, 1),
#   (38998, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28669, 0),
#   (28642, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'fashion': [(23714, 1),
#   (31689, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28675, 0),
#   (28669, 0),
#   (28473, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'father': [(6305, 1),
#   (39276, 1),
#   (45, 0),
#   (28669, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28680, 0),
#   (28675, 0),
#   (28474, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28511, 0),
#   (28473, 0),
#   (28759, 0),
#   (28441, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'fathers': [(3216, 1),
#   (34567, 1),
#   (20423, 1),
#   (22357, 1),
#   (40528, 1),
#   (28705, 0),
#   (28595, 0),
#   (28717, 0),
#   (28709, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28628, 0),
#   (28695, 0),
#   (28642, 0),
#   (28474, 0),
#   (28669, 0),
#   (28675, 0),
#   (28708, 0),
#   (28680, 0),
#   (28688, 0),
#   (28511, 0),
#   (28441, 0),
#   (28473, 0),
#   (28316, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'fear': [(8100, 1),
#   (34545, 1),
#   (41122, 1),
#   (34557, 1),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28430, 0),
#   (28441, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0)],
#  'federal': [(26666, 1),
#   (28473, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (45, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28642, 0),
#   (28441, 0),
#   (28752, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'feelings': [(28415, 1),
#   (21299, 1),
#   (45, 0),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28473, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28430, 0),
#   (28441, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'female': [(10686, 1),
#   (35572, 1),
#   (19576, 1),
#   (40821, 1),
#   (36833, 1),
#   (32401, 1),
#   (10376, 1),
#   (23216, 1),
#   (12012, 1),
#   (31329, 1),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28628, 0),
#   (28595, 0),
#   (28473, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28474, 0),
#   (45, 0),
#   (28441, 0)],
#  'feminine': [(36527, 1),
#   (19647, 1),
#   (39367, 1),
#   (2596, 1),
#   (28415, 1),
#   (29236, 1),
#   (23390, 1),
#   (32446, 1),
#   (25978, 1),
#   (21299, 1),
#   (28567, 0),
#   (28556, 0),
#   (28550, 0),
#   (28628, 0),
#   (28531, 0),
#   (28527, 0),
#   (28595, 0),
#   (28675, 0),
#   (28642, 0),
#   (28669, 0),
#   (28474, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28511, 0),
#   (28430, 0),
#   (28473, 0)],
#  'femininity': [(34428, 1),
#   (5640, 1),
#   (4401, 1),
#   (12559, 1),
#   (45, 0),
#   (28474, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28511, 0),
#   (28473, 0),
#   (28752, 0),
#   (28316, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'feminism': [(30540, 1),
#   (28316, 1),
#   (40944, 1),
#   (18276, 1),
#   (35287, 1),
#   (18802, 1),
#   (37368, 1),
#   (17043, 1),
#   (28567, 1),
#   (28527, 1),
#   (17615, 1),
#   (18210, 1),
#   (18021, 1),
#   (41726, 1),
#   (40510, 1),
#   (24680, 1),
#   (12549, 1),
#   (34957, 1),
#   (26839, 1),
#   (31271, 1),
#   (37638, 1),
#   (32233, 1),
#   (16118, 1),
#   (26067, 1),
#   (35678, 1),
#   (4926, 1),
#   (37519, 1),
#   (28150, 1),
#   (1980, 1),
#   (32436, 1)],
#  'feminismpostmodernism': [(3481, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28752, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'feminisms': [(1303, 1),
#   (8068, 1),
#   (32007, 1),
#   (32861, 1),
#   (45, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28473, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28430, 0),
#   (28441, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0)],
#  'feminist': [(36662, 1),
#   (26852, 1),
#   (6360, 1),
#   (30913, 1),
#   (37866, 1),
#   (16393, 1),
#   (34094, 1),
#   (34515, 1),
#   (28353, 1),
#   (8566, 1),
#   (37280, 1),
#   (545, 1),
#   (10686, 1),
#   (39799, 1),
#   (6305, 1),
#   (5090, 1),
#   (34894, 1),
#   (28767, 1),
#   (19020, 1),
#   (12417, 1),
#   (32061, 1),
#   (17255, 1),
#   (32077, 1),
#   (37028, 1),
#   (4851, 1),
#   (15983, 1),
#   (39276, 1),
#   (277, 1),
#   (40728, 1),
#   (28527, 0)],
#  'feminizing': [(5405, 1),
#   (39609, 1),
#   (40158, 1),
#   (41768, 1),
#   (28642, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (45, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28474, 0),
#   (28473, 0),
#   (28752, 0),
#   (28302, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0)],
#  'fertile': [(13367, 1),
#   (13506, 1),
#   (45, 0),
#   (28669, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28473, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28441, 0),
#   (28759, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'fertility': [(12441, 1),
#   (45, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28473, 0),
#   (29365, 0),
#   (28441, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0),
#   (28270, 0)],
#  'fever': [(9598, 1),
#   (45, 0),
#   (28669, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28473, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28441, 0),
#   (29365, 0),
#   (28302, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'fiction': [(29337, 1),
#   (22542, 1),
#   (9026, 1),
#   (31437, 1),
#   (14345, 1),
#   (36984, 1),
#   (38641, 1),
#   (31329, 1),
#   (34888, 1),
#   (5095, 1),
#   (19576, 1),
#   (27384, 1),
#   (33780, 1),
#   (28271, 1),
#   (28675, 0),
#   (28287, 0),
#   (28280, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28321, 0),
#   (28556, 0),
#   (28270, 0),
#   (28680, 0),
#   (28267, 0),
#   (28264, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0)],
#  'fictions': [(34248, 1),
#   (32445, 1),
#   (28669, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28473, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28441, 0),
#   (28759, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'field': [(34741, 1),
#   (45, 0),
#   (28642, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28669, 0),
#   (28441, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28752, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  'fifth': [(12279, 1),
#   (28473, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28474, 0),
#   (28441, 0),
#   (29365, 0),
#   (28430, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'fight': [(5532, 1),
#   (4300, 1),
#   (10379, 1),
#   (16185, 1),
#   (10557, 1),
#   (45, 0),
#   (28669, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28628, 0),
#   (28642, 0),
#   (28675, 0),
#   (28527, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28723, 0),
#   (28531, 0),
#   (28511, 0),
#   (28759, 0),
#   (28319, 0),
#   (28253, 0),
#   (28264, 0),
#   (28267, 0)],
#  'fighting': [(34264, 1),
#   (21873, 1),
#   (35170, 1),
#   (28098, 1),
#   (3918, 1),
#   (33947, 1),
#   (27513, 1),
#   (35156, 1),
#   (32725, 1),
#   (30030, 1),
#   (22566, 1),
#   (29597, 1),
#   (29606, 1),
#   (33265, 1),
#   (34315, 1),
#   (34305, 1),
#   (32846, 1),
#   (34291, 1),
#   (25895, 1),
#   (35862, 1),
#   (34280, 1),
#   (33574, 1),
#   (33988, 1),
#   (29734, 1),
#   (28709, 1),
#   (35599, 1),
#   (31186, 1),
#   (35631, 1),
#   (33049, 1),
#   (31588, 1)],
#  'figuring': [(22408, 1),
#   (45, 0),
#   (28628, 0),
#   (28474, 0),
#   (28511, 0),
#   (28527, 0),
#   (28531, 0),
#   (28550, 0),
#   (28556, 0),
#   (28567, 0),
#   (28595, 0),
#   (28642, 0),
#   (28441, 0),
#   (28669, 0),
#   (28675, 0),
#   (28680, 0),
#   (28688, 0),
#   (28695, 0),
#   (28705, 0),
#   (28708, 0),
#   (28709, 0),
#   (28717, 0),
#   (28473, 0),
#   (28430, 0),
#   (28205, 0),
#   (28287, 0),
#   (28214, 0),
#   (28224, 0),
#   (28253, 0),
#   (28264, 0)],
#  ...}
